# %%
# !git clone https://github.com/longday1102/VietAI-experiment-LLaMA2.git
# Out:
# Cloning into 'VietAI-experiment-LLaMA2'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (90/90), done.
# remote: Compressing objects: 100% (88/88), done.
# Receiving objects: 100% (90/90), 25.00 KiB | 1.04 MiB/s, done.
# remote: Total 90 (delta 44), reused 0 (delta 0), pack-reused 0
# Resolving deltas: 100% (44/44), done.

# %%
# !git pull
# Out:
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
# %cd /kaggle/working/VietAI-experiment-LLaMA2
# Out:
# /kaggle/working/VietAI-experiment-LLaMA2

# %%
# !pip install --upgrade -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 18.0 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 kB 5.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 18.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 MB 13.3 MB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.30.2
#     Uninstalling transformers-4.30.2:
#       Successfully uninstalled transformers-4.30.2
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.20.3
#     Uninstalling accelerate-0.20.3:
#       Successfully uninstalled accelerate-0.20.3
# ...

# %%
from huggingface_hub import login
login()

# %%
# !torchrun --standalone --nproc_per_node=2 run.py --model_checkpoint="meta-llama/Llama-2-7b-hf"\
                                                 --test_size=0.05 --max_length=512\
                                                 --batch_size=1 --epochs=3\
                                                 --save_state_name="llama-2-7b-hf-state_checkpoint.pt"\
                                                 --save_model_name="llama-2-7b-hf-model-checkpoint"\
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# ...
